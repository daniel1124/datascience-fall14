# %%
# %matplotlib inline

# Import several libraries
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('Nile.csv')

# %%
data[:5]
# Out:
#    Unnamed: 0  time  Nile
# 0           1  1871  1120
# 1           2  1872  1160
# 2           3  1873   963
# 3           4  1874  1210
# 4           5  1875  1160
#
# [5 rows x 3 columns]

# %%
plt.plot(data['time'],data['Nile'])

# %%
plt.bar(data['time'],data['Nile'])
# Out:
# <Container object of 100 artists>
