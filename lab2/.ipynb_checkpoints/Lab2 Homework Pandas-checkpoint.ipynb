# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %pylab inline

# %%
players = pd.read_csv('players.csv')
events = pd.read_csv('events.csv')
countries = pd.read_csv('countries.csv')

# %% [markdown]
# ### Problem 1

# %%
players['name'].str.extract('([AEIOU])').count()
# Out:
# 114

# %% [markdown]
# ### Problem 2

# %%
players[(players.name.str.contains('^A')) & (players.country_id == 'USA')]
# Out:
#                                         name   player_id country_id  \
# 1   Aaron Peirsol                             PEIRSAAR01        USA
# 3   Adam Nelson                               NELSOADA01        USA
# 15  Allyson Felix                             FELIXALL01        USA
# 16  Alvin Harrison                            HARRIALV01        USA
# 17  Amanda Beard                              BEARDAMA01        USA
# 18  Amanda Weir                               WEIRAMA01         USA
# 19  Amy van Dyken                             VANDYAMY01        USA
# 25  Angelo Taylor                             TAYLOANG02        USA
# 30  Anthony Ervin                             ERVINANT01        USA
# 32  Antonio Pettigrew                         PETTIANT01        USA
#
#      birthdate
# 1   1978-08-26
# 3   1984-10-13
# 15  1975-01-04
# 16  1976-05-15
# 17  1980-10-22
# 18  1979-01-09
# 19  1983-07-26
# 25  1974-08-24
# 30  1972-02-14
# 32  1976-03-21
#
# [10 rows x 4 columns]

# %% [markdown]
# ### Problem 3

# %%
res = players.groupby('country_id').size()

country_dict = pd.Series(list(countries.name), index=list(countries.country_id))

pd.DataFrame(
    {'country_name': country_dict,
    'num_players' : res}
)
# Out:
#                                  country_name  num_players
# ALG  Algeria                                             4
# ARG  Argentina                                           1
# AUS  Australia                                          34
# AUT  Austria                                             2
# BAH  The Bahamas                                         5
# BAR  Barbados                                            1
# BLR  Belarus                                             7
# BRA  Brazil                                              9
# BUL  Bulgaria                                            1
# CAN  Canada                                              1
# CHN  China                                               8
# CMR  Cameroon                                            1
# CRC  Costa Rica                                          1
# CRO  Croatia                                             1
# CUB  Cuba                                               12
# ...

# %% [markdown]
# ### Problem 4

# %%
psub = players[players.birthdate.str.contains('1975')]

joined = pd.merge(countries, psub, on='country_id',how='left').groupby('name_x').count().name_y

joined
# Out:
# name_x
# Algeria                                     0
# Argentina                                   0
# Australia                                   3
# Austria                                     0
# Barbados                                    0
# Belarus                                     1
# Brazil                                      1
# Bulgaria                                    0
# Cameroon                                    0
# Canada                                      0
# China                                       0
# Costa Rica                                  0
# Croatia                                     0
# Cuba                                        1
# Czech Republic                              1
# Denmark                                     1
# Dominican Republic                          0
# Eritrea                                     1
# Estonia                                     1
# Ethiopia                                    1
# ...
